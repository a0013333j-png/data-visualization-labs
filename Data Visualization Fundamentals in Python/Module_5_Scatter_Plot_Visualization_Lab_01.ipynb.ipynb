# %%
#Preamble code

import seaborn as sns
import pandas as pd

# %%
#Skeleton code
#Learners will complete this code
#Task: Modify the following code to generate a scatter plot that shows tips for different days of the week, with color representing the gender of the customer.  You can use pandas to explore the data first, by uploading the tips dataset and describing the data using data.head() or data.info()

# Apply the default theme
sns.set_theme()

# %%
# Load an example dataset
tips = sns.load_dataset("tips")
data = pd.read_csv("tips.csv")

# %%
#exploring data
#your code goes here
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Create a visualization
# your code goes here
import matplotlib.pyplot as plt  
plt.figure(figsize=(8,6))
sns.scatterplot(x='total_bill', y='tip', hue='day', data=tips, palette='Set2')
plt.title('Scatter Plot of Tips by Day of the Week')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()
